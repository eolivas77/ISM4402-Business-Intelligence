# %% [markdown]
# # Your Turn Page 53

# %%
import pandas as pd
import numpy as np

#Set dataframe
Location = "datasets/gradedata.csv"
df = pd.read_csv(Location)
df.tail()

#Randomly select 500 rows from dataset
print(df.take(np.random.permutation(len(df))[:500]))
# Out:
#           fname       lname  gender  age  exercise  hours  grade  \
# 1440     Declan      Warner    male   14         4     12   89.7
# 80         Hoyt       Lyons    male   16         5      1   71.3
# 858     Brenden      Slater    male   16         1     14   89.7
# 1167     Whoopi        Lane  female   17         4     11   89.7
# 506        Noah      Suarez    male   16         1     12   82.6
# 505       Sonia       Kelly  female   17         4      7   83.6
# 663      Colton     Charles    male   17         5      8   80.1
# 1953       Erin     Mercado  female   15         4      9   71.4
# 459        Inez  Stephenson  female   17         5     17  100.0
# 15        Medge    Mccarthy  female   15         1      8   75.8
# 128   Shaeleigh     Clayton  female   19         2     12   92.4
# 236      Teagan     Mullins  female   15         1     12   91.3
# 604      Kessie    Gonzalez  female   19         3     13   86.4
# ...
